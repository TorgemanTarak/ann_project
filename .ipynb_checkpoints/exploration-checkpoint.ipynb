# %%
from helpers import *
from scipy import stats
import plotly.express as px
import pandas as pd
import seaborn as sns
import bornly as bx
import torch
from torch import nn
device = torch.device("cuda:0")
from mpl_toolkits.mplot3d import Axes3D
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
import torch
torch.manual_seed(0)
import random
random.seed(0)
np.random.seed(0)
torch.use_deterministic_algorithms(False) # got an error when setting this to True so reproducibility wont be perfectly possible

# %% [markdown]
# ## Just some exploration

# %% [markdown]
# $$rt + γq_{t-1}(st+1, at+1) -q_t(st,at)$$ at+1 comes from the policy

# %%
#pip install gym[classic_control]

# %%
num_episodes=100
num_step=200

# %%
# Create the Pendulum environment
env = NormalizedEnv(gym.make('Pendulum-v1',render_mode="human"))
#agent = RandomAgent(env)
agent= HeuristicPendulumAgent(env,1)
# Set the environment to the initial state
state = env.reset()
average_total_reward = 0
# Run the simulation for 10 time steps
for e in range(num_episodes):
    state = env.reset()[0]
    total_reward = 0
    for t in range(num_step):
        # Render the environment
        env.render()

        # Take a random action
        action = agent.compute_action(state)
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        total_reward += reward
    # Close the environment
    average_total_reward+=total_reward/num_episodes
env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17512\2208524244.py in <module>
#      12     for t in range(num_step):
#      13         # Render the environment
# ---> 14         env.render()
#      15
#      16         # Take a random action
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, *args, **kwargs)
#     327     ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328         """Renders the environment."""
# --> 329         return self.env.render(*args, **kwargs)
#     330
#     331     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, *args, **kwargs)
#     327     ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328         """Renders the environment."""
# --> 329         return self.env.render(*args, **kwargs)
#     330
#     331     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\wrappers\order_enforcing.py in render(self, *args, **kwargs)
#      49                 "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50             )
# ---> 51         return self.env.render(*args, **kwargs)
#      52
#      53     @property
#
# ~\anaconda3\lib\site-packages\gym\wrappers\env_checker.py in render(self, *args, **kwargs)
#      53             return env_render_passive_checker(self.env, *args, **kwargs)
#      54         else:
# ---> 55             return self.env.render(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\gym\envs\classic_control\pendulum.py in render(self)
#     251         if self.render_mode == "human":
#     252             pygame.event.pump()
# --> 253             self.clock.tick(self.metadata["render_fps"])
#     254             pygame.display.flip()
#     255
#
# KeyboardInterrupt:

# %%
import pygame
pygame.display.quit()
pygame.quit()

# %% [markdown]
# ## Comparaison between random agent and heuristic agent

# %% [markdown]
# ### average reward for the random agent on 10 episodes

# %%
# Create the Pendulum environment
env = NormalizedEnv(gym.make('Pendulum-v1'))
agent = RandomAgent(env)

# Set the environment to the initial state
state = env.reset()
RA_list_total_reward = []
# Run the simulation for 10 time steps
for e in range(10):
    state = env.reset()[0]
    total_reward = 0
    for t in range(num_step):
        # Render the environment
        env.render()

        # Take a random action
        action = agent.compute_action(state)
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        total_reward += reward
    # Close the environment
    RA_list_total_reward.append(total_reward)
env.close()
# Out:
# C:\Users\torge\anaconda3\lib\site-packages\gym\envs\classic_control\pendulum.py:167: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("Pendulum-v1", render_mode="rgb_array")
#   gym.logger.warn(

# %%
print("Average cummulative reward for Random agent on 10 episodes : ",sum(RA_list_total_reward)/len(RA_list_total_reward))
# Out:
# Average cummulative reward for Random agent on 10 episodes :  -1265.3077368415827

# %%
# Create the Pendulum environment
env = NormalizedEnv(gym.make('Pendulum-v1'))
agent = RandomAgent(env)

# Set the environment to the initial state
state = env.reset()
RA_list_total_reward = []

for e in range(num_episodes):
    state = env.reset()[0]
    total_reward = 0
    for t in range(num_step):
        # Render the environment
        env.render()

        # Take a random action
        action = agent.compute_action(state)
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        total_reward += reward
    # Close the environment
    RA_list_total_reward.append(total_reward)
env.close()

# %%
# Create the Pendulum environment
env = NormalizedEnv(gym.make('Pendulum-v1'))
agent= HeuristicPendulumAgent(env,0.3)

# Set the environment to the initial state
state = env.reset()
HA_list_total_reward = []
# Run the simulation for 10 time steps
for e in range(num_episodes):
    state = env.reset()[0]
    total_reward = 0
    for t in range(num_step):
        # Render the environment
        env.render()

        # Take a random action
        action = agent.compute_action(state)
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        total_reward += reward
    # Close the environment
    HA_list_total_reward.append(total_reward)
env.close()

# %%
data = list(map(lambda x: ('HA',x),HA_list_total_reward)) + list(map(lambda x: ('RA',x),RA_list_total_reward))

# %%
df = pd.DataFrame(data,columns=['policy','total_reward'])

# %%
plot = sns.barplot(data=df, x="policy", y="total_reward")

plot.get_figure().savefig('figures/average total reward per episode HA vs RA.png')

# %%
stats.ttest_ind(HA_list_total_reward,RA_list_total_reward,equal_var = False)
# Out:
# Ttest_indResult(statistic=0.6949462454144771, pvalue=0.48717075203408466)

# %% [markdown]
# Running on 1000 episodes the Welch’s t-test shows that the HA gets a better total reward on average that RA

# %%
df = pd.DataFrame(columns=['torque', 'total_reward'])

# %%
num_episodes=1000

# %%
# Create the Pendulum environment
env = NormalizedEnv(gym.make('Pendulum-v1'))
agent= HeuristicPendulumAgent(env)

# Set the environment to the initial state
state = env.reset()

# Run the simulation for 10 values of torque
average_reward_torque = []
for torque in np.linspace(0.1, 1, num=10):
    average_total_reward = 0
    agent = HeuristicPendulumAgent(env,torque)
    for e in range(num_episodes):
        state = env.reset()[0]
        total_reward = 0
        for t in range(num_step):
            # Render the environment
            env.render()

            # Take a random action
            action = agent.compute_action(state)
            next_state, reward, terminated, truncated , info = env.step(action)
            state = next_state
            total_reward += reward
        # Close the environment
        
        average_total_reward += (total_reward)/num_episodes
        new_row=(torque,total_reward)
        df = pd.concat([df, pd.DataFrame([new_row], columns=df.columns)], ignore_index=True)
    average_reward_torque.append(average_total_reward)
env.close()
# Out:
# C:\Users\torge\anaconda3\lib\site-packages\gym\envs\classic_control\pendulum.py:167: UserWarning:
#
# WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("Pendulum-v1", render_mode="rgb_array")

# %%
ax = sns.lineplot(data=df, x="torque", y="total_reward")
ax.set_title('average total reward per episode as a function of the torque')
ax.figure.savefig('figures/average total reward per episode as a function of the torque.png')

# %% [markdown]
# Buffer and stuff

# %% [markdown]
# class Buffer:
#     def __init__(self, capacity=10000,state_dim=3,action_dim=1):
#
#         self.capacity = capacity
#
#
#
#         self.num_samples = 0
#
#         # followong SARSA we need to store: state ,action ,reward ,next state ,next action
#         self.state_tape = torch.zeros((self.capacity, state_dim))
#         self.action_tape = torch.zeros((self.capacity, action_dim))
#         self.reward_tape = torch.zeros((self.capacity, 1))
#         self.next_state_tape = torch.zeros((self.capacity, state_dim))
#         self.next_action_tape = torch.zeros((self.capacity, action_dim))
#
#     def add(self, sample):
#        # sample = (state, action, reward, next_state, next_action)
#         #to replace
#         index = self.num_samples % self.capacity
#
#         self.state_tape[index] = torch.from_numpy(sample[0])
#         self.action_tape[index] = sample[1]
#         self.reward_tape[index] = sample[2]
#         self.next_state_tape[index] = torch.from_numpy(sample[3])
#         self.next_action_tape[index] = sample[4]
#         self.num_samples += 1
#     def sample_batch(self,batch_size):
#         record_range = min(self.num_samples, self.capacity)
#         indices = torch.randint(0,record_range,size=(batch_size,))
#         return indices
#
#
#
#
#
# class Qnetwork(nn.Module):
#     def __init__(self,state_dim=3,action_dim=1,hidden_dim=32):
#         super().__init__()
#         self.input_shape = state_dim + action_dim
#         self.fc1 = nn.Linear(self.input_shape,hidden_dim)
#         self.fc2 = nn.Linear(hidden_dim,hidden_dim)
#         self.fc3 = nn.Linear(hidden_dim,1)
#         self.activation=nn.ReLU()
#     def forward(self,x):
#         output = self.fc1(x)
#         output = self.activation(output)
#         output = self.fc2(output)
#         output = self.activation(output)
#         output = self.fc3(output)
#         return output

# %%
model = Qnetwork().to(device)
target = Qnetwork().to(device)
for param in target.parameters():
        param.requires_grad = False
EMA(model,target,1)
buffer=Buffer()


episodes=1000
batch_size=128
lr=1e-4
beta=1
gamma=0.99
loss=torch.nn.MSELoss()
optimizer=torch.optim.Adam(model.parameters(),lr)

# %%
losses = []

# %%
def train_one_batch(model,target,buffer,indexes):
            
        optimizer.zero_grad()
        
        action_batch = buffer.action_tape[indexes]
        state_batch = buffer.state_tape[indexes]
        next_action_batch = buffer.next_action_tape[indexes]
        next_state_batch = buffer.next_state_tape[indexes]
        reward_batch = buffer.reward_tape[indexes].to(device)
       
        input_model = torch.cat((state_batch,action_batch),dim=1).to(device)
        input_target = torch.cat((next_state_batch,next_action_batch),dim=1).to(device)
        x = model(input_model)
        y = reward_batch + gamma*target(input_target)
       
        l=loss(x,y)
        l.backward()
        EMA(model,target,beta)
        optimizer.step()
       
        
        return l.item()

# %%
env = NormalizedEnv(gym.make('Pendulum-v1'))
#agent = RandomAgent(env)
agent= HeuristicPendulumAgent(env,0.6)
# Set the environment to the initial state
state = env.reset()
average_total_reward = 0
# Run the simulation for 10 time steps
losses=[]
for e in tqdm(range(episodes)):
    state = env.reset()[0]
    total_reward = 0
    episodic_loss = 0
    for t in range(200):
        # Render the environment
        env.render()
        previous_state = state
        # Take a random action
        action = agent.compute_action(state)
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        total_reward += reward
        next_action = agent.compute_action(next_state)
        sample = (previous_state,action,reward,next_state,next_action)
        buffer.add(sample)
        
        
        batches_indexes=buffer.sample_batch(batch_size)
        if buffer.num_samples >128:
            step_loss = train_one_batch(model,target,buffer,batches_indexes)
            episodic_loss+=step_loss

    losses.append(episodic_loss)
    # Close the environment
    average_total_reward+=total_reward/num_episodes
torch.save(model.state_dict(), 'models/critic_no_actor2.pth')
env.close()
# Out:
#  38%|██████████████████████████████▍                                                | 385/1000 [03:41<05:54,  1.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11996\1719222714.py in <module>
#      27         batches_indexes=buffer.sample_batch(batch_size)
#      28         if buffer.num_samples >128:
# ---> 29             step_loss = train_one_batch(model,target,buffer,batches_indexes)
#      30             episodic_loss+=step_loss
#      31
#
# ~\AppData\Local\Temp\ipykernel_11996\2737657161.py in train_one_batch(model, target, buffer, indexes)
#      15
#      16         l=loss(x,y)
# ---> 17         l.backward()
#      18         EMA(model,target,beta)
#      19         optimizer.step()
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     486                 inputs=inputs,
#     487             )
# --> 488         torch.autograd.backward(
#     489             self, gradient, retain_graph, create_graph, inputs=inputs
#     490         )
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
x=list(range(len(losses)))
y=losses
plt.plot(x,y)
plt.xlabel('episode')
plt.ylabel('cumulative MSEloss per episode')
plt.savefig('figures/training_curve_critic_part4.png')

# %%
def polar_plot(speed,action,model,model_name=''):
    pi=torch.acos(torch.zeros(1)).item() * 2
    radius = torch.linspace(0, 1, 100)
    angle = torch.linspace(0, 2 * pi, 100)
    x=torch.cos(angle)
    y=torch.sin(angle)
    z=torch.zeros(angle.shape[0],radius.shape[0])
    
    
    for i in range(x.shape[0]):
        inp = torch.tensor([x[i],y[i],speed,action]).to(device)
        # z is constant with respect to the radius
        z[i,:] = model(inp)
    angle = angle.detach().numpy()
    z = z.detach().numpy()
    radius = radius.detach().numpy()

    fig = plt.figure()
    ax = Axes3D(fig)
    r, th = np.meshgrid(radius, angle)
    plt.subplot(projection="polar")

    plt.pcolormesh(th, r, z)
    #plt.pcolormesh(th, z, r)

    plt.plot(angle, r, color='k', ls='none') 
    plt.grid()

    plt.show()
    plt.savefig('figures/'+model_name+'_polar_map_speed_'+str(speed)+'_action_'+str(action)+'_part4.png')

# %%
before_train= Qnetwork().to(device)

# %%
polar_plot(0,-0.6,model,'after_train')
polar_plot(0,-0.6,before_train,'before_train')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:19: MatplotlibDeprecationWarning:
#
# Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:23: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %%
polar_plot(0,0.6,model,'after_train')
polar_plot(0,0.6,before_train,'before_train')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:19: MatplotlibDeprecationWarning:
#
# Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:23: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %%
polar_plot(0,0.0,model,'after_train')
polar_plot(0,0.0,before_train,'before_train')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:19: MatplotlibDeprecationWarning:
#
# Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:23: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %%
polar_plot(1,-0.6,model,'after_train')
polar_plot(1,-0.6,before_train,'before_train')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:19: MatplotlibDeprecationWarning:
#
# Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:23: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %%
polar_plot(-0.6,-0.6,model,'after_train')
polar_plot(-0.6,-0.6,before_train,'before_train')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:19: MatplotlibDeprecationWarning:
#
# Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#
# C:\Users\torge\AppData\Local\Temp\ipykernel_27056\1989296979.py:23: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %% [markdown]
# actor stuff

# %%
from tqdm import tqdm

buffer = Buffer(100000)


critic = Qnetwork().to(device)
critic_target = Qnetwork().to(device)
for param in critic_target.parameters():
        param.requires_grad = False
EMA(critic,critic_target,1)

sigma=0.3

actor = PolicyNetwork().to(device)
actor_target = PolicyNetwork().to(device)
for param in actor_target.parameters():
        param.requires_grad = False
EMA(actor,actor_target,1)
agent = DDPGAgent(actor,sigma,vanilla_noise=True)
target_agent = DDPGAgent(actor_target,sigma,True)
        

episodes=1000
batch_size=128
lr_critic=0.0001
lr_actor=0.0001
beta=0.05
gamma=0.99
loss=torch.nn.MSELoss()
optimizer_critic=torch.optim.Adam(critic.parameters(),lr_critic)
optimizer_actor=torch.optim.Adam(agent.model.parameters(),lr_actor)

#num_batches = buffer.capacity // batch_size
#permutation = torch.randperm(buffer.capacity)
#batches = torch.chunk(permutation[:num_batches * batch_size], num_batches)

# %%
def train_one_batch_a2c(critic,critic_target,agent,target_agent,buffer,indexes):
            
       
        
        action_batch = buffer.action_tape[indexes].to(device)
        state_batch = buffer.state_tape[indexes].to(device)
        next_state_batch = buffer.next_state_tape[indexes].to(device)
        reward_batch = buffer.reward_tape[indexes].to(device)
        
        
       
    
        #critic loop
        optimizer_critic.zero_grad()
        target_actions = target_agent.compute_action(next_state_batch,deterministic=True)
            
        input_model = torch.cat((state_batch,action_batch),dim=1)
        input_target = torch.cat((next_state_batch,target_actions),dim=1)
        
        x = critic(input_model)
        y = reward_batch + gamma*critic_target(input_target)
       
        loss_critic = loss(x,y)
        loss_critic.backward()
        
        optimizer_critic.step()
        EMA(critic,critic_target,beta)
        
        #actor loop
        optimizer_actor.zero_grad()
        
        actions = agent.compute_action(state_batch,deterministic=True)
        input_critic =  torch.cat((state_batch,actions),dim=1)
        critic_output = critic(input_critic)
        loss_actor  = -torch.mean(critic_output)
        loss_actor.backward()
        optimizer_actor.step()
        EMA(agent.model,target_agent.model,beta)
        
        
        return (loss_critic.item() , loss_actor.item())

# %%
env = NormalizedEnv(gym.make('Pendulum-v1'))
#agent = RandomAgent(env)

# Set the environment to the initial state
state = env.reset()
average_total_reward = 0
# Run the simulation for 10 time steps
losses_critic = []
losses_actor = []
for e in tqdm(range(episodes)):
    state = env.reset()[0]
    total_reward = 0
    episodic_loss_critic = 0
    episodic_loss_actor = 0
    for t in range(200):
        # Render the environment
        env.render()
        previous_state = state
        
        # Take a random action
        state=torch.from_numpy(state).to(device)
        action = agent.compute_action(state,False).detach().cpu().numpy()
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        
        total_reward += reward
        next_action = -1
        action = torch.from_numpy(action)
        sample = (previous_state,action,reward,next_state,next_action)
        buffer.add(sample)
        
        
        batches_indexes=buffer.sample_batch(batch_size)
        step_loss_critic, step_loss_actor = train_one_batch_a2c(critic,critic_target,agent,target_agent,buffer,batches_indexes)
        episodic_loss_critic+=step_loss_critic
        episodic_loss_actor+=step_loss_actor
        
        
    losses_critic.append(episodic_loss_critic)
    losses_actor.append(episodic_loss_actor)
    # Close the environment
    average_total_reward+=total_reward/num_episodes
env.close()

# %%
import matplotlib.pyplot as plt
x=list(range(len(losses_critic)))
y=losses_critic
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
x=list(range(len(losses_actor)))
y=losses_actor
plt.plot(x,y)

# %%
# Create the Pendulum environment
env = NormalizedEnv(gym.make('Pendulum-v1',render_mode="human"))
#agent = RandomAgent(env)

# Set the environment to the initial state
state = env.reset()
average_total_reward = 0
# Run the simulation for 10 time steps
for e in range(5):
    state = env.reset()[0]
    total_reward = 0
    for t in range(num_step):
        # Render the environment
        env.render()

        # Take a random action
        state=torch.from_numpy(state).to(device)
        action = agent.compute_action(state,True).detach().cpu().numpy()
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        total_reward += reward
    # Close the environment
    average_total_reward+=total_reward/num_episodes
env.close()

# %%
import pygame
pygame.display.quit()
pygame.quit()

# %% [markdown]
# **part5**

# %%
torch.save(critic.state_dict(), 'model_weights.pth')

# %%
from tqdm import tqdm

buffer = Buffer(100000)


critic = Qnetwork().to(device)
critic_target = Qnetwork().to(device)
for param in critic_target.parameters():
        param.requires_grad = False
EMA(critic,critic_target,1)

sigma=0.3

actor = PolicyNetwork().to(device)
actor_target = PolicyNetwork().to(device)
for param in actor_target.parameters():
        param.requires_grad = False
EMA(actor,actor_target,1)
agent = DDPGAgent(actor,sigma,vanilla_noise=False)
target_agent = DDPGAgent(actor_target,sigma,False)
        

episodes=1000
batch_size=128
lr_critic=0.0001
lr_actor=0.0001
beta=0.005
gamma=0.99
loss=torch.nn.MSELoss()
optimizer_critic=torch.optim.Adam(critic.parameters(),lr_critic)
optimizer_actor=torch.optim.Adam(agent.model.parameters(),lr_actor)

#num_batches = buffer.capacity // batch_size
#permutation = torch.randperm(buffer.capacity)
#batches = torch.chunk(permutation[:num_batches * batch_size], num_batches)

# %%
def train_one_batch_a2c(critic,critic_target,agent,target_agent,buffer,indexes):
            
       
        
        action_batch = buffer.action_tape[indexes].to(device)
        state_batch = buffer.state_tape[indexes].to(device)
        next_state_batch = buffer.next_state_tape[indexes].to(device)
        reward_batch = buffer.reward_tape[indexes].to(device)
        
        
       
    
        #critic loop
        optimizer_critic.zero_grad()
        target_actions = target_agent.compute_action(next_state_batch,deterministic=True)
            
        input_model = torch.cat((state_batch,action_batch),dim=1)
        input_target = torch.cat((next_state_batch,target_actions),dim=1)
        
        x = critic(input_model)
        y = reward_batch + gamma*critic_target(input_target)
       
        loss_critic = loss(x,y)
        loss_critic.backward()
        
        optimizer_critic.step()
        EMA(critic,critic_target,beta)
        
        #actor loop
        optimizer_actor.zero_grad()
        
        actions = agent.compute_action(state_batch,deterministic=True)
        input_critic =  torch.cat((state_batch,actions),dim=1)
        critic_output = critic(input_critic)
        loss_actor  = -torch.mean(critic_output)
        loss_actor.backward()
        optimizer_actor.step()
        EMA(agent.model,target_agent.model,beta)
        
        
        return (loss_critic.item() , loss_actor.item())

# %%
env = NormalizedEnv(gym.make('Pendulum-v1'))
#agent = RandomAgent(env)

# Set the environment to the initial state
state = env.reset()
average_total_reward = 0
# Run the simulation for 10 time steps
losses_critic = []
losses_actor = []
episodic_rewards = []
for e in tqdm(range(episodes)):
    state = env.reset()[0]
    total_reward = 0
    episodic_loss_critic = 0
    episodic_loss_actor = 0
    for t in range(200):
        # Render the environment
        env.render()
        previous_state = state
        
        # Take a random action
        state=torch.from_numpy(state).to(device)
        action = agent.compute_action(state,False).detach().cpu().numpy()
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        
        total_reward += reward
        next_action = -1
        action = torch.from_numpy(action)
        sample = (previous_state,action,reward,next_state,next_action)
        buffer.add(sample)
        
        
        batches_indexes=buffer.sample_batch(batch_size)
        if buffer.num_samples >128:
            step_loss_critic, step_loss_actor = train_one_batch_a2c(critic,critic_target,agent,target_agent,buffer,batches_indexes)
            episodic_loss_critic+=step_loss_critic
            episodic_loss_actor+=step_loss_actor
        
        
    losses_critic.append(episodic_loss_critic)
    losses_actor.append(episodic_loss_actor)
    episodic_rewards.append(total_reward)
    # Close the environment
    average_total_reward+=total_reward/num_episodes
env.close()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [20:32<00:00,  1.23s/it]

# %%
import matplotlib.pyplot as plt
x=list(range(len(losses_critic)))
y=losses_critic
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
x=list(range(len(losses_actor)))
y=losses_actor
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
x=list(range(len(episodic_rewards)))
y=episodic_rewards
plt.plot(x,y)

# %% [markdown]
# Part 5 plots

# %%
from tqdm import tqdm

buffer = Buffer(100000)


critic = Qnetwork().to(device)
critic_target = Qnetwork().to(device)
for param in critic_target.parameters():
        param.requires_grad = False
EMA(critic,critic_target,1)

sigma=0.3

actor = PolicyNetwork().to(device)
actor_target = PolicyNetwork().to(device)
for param in actor_target.parameters():
        param.requires_grad = False
EMA(actor,actor_target,1)
agent = DDPGAgent(actor,sigma,vanilla_noise=True)
target_agent = DDPGAgent(actor_target,sigma,True)
        

episodes=1000
batch_size=128
lr_critic=0.0001
lr_actor=0.0001
beta=1
gamma=0.99
loss=torch.nn.MSELoss()
optimizer_critic=torch.optim.Adam(critic.parameters(),lr_critic)
optimizer_actor=torch.optim.Adam(agent.model.parameters(),lr_actor)

#num_batches = buffer.capacity // batch_size
#permutation = torch.randperm(buffer.capacity)
#batches = torch.chunk(permutation[:num_batches * batch_size], num_batches)

# %%
def train_one_batch_a2c_no_ema(critic,critic_target,agent,target_agent,buffer,indexes):
            
       
        
        action_batch = buffer.action_tape[indexes].to(device)
        state_batch = buffer.state_tape[indexes].to(device)
        next_state_batch = buffer.next_state_tape[indexes].to(device)
        reward_batch = buffer.reward_tape[indexes].to(device)
        
        
       
    
        #critic loop
        optimizer_critic.zero_grad()
        target_actions = target_agent.compute_action(next_state_batch,deterministic=True)
            
        input_model = torch.cat((state_batch,action_batch),dim=1)
        input_target = torch.cat((next_state_batch,target_actions),dim=1)
        
        x = critic(input_model)
        y = reward_batch + gamma*critic_target(input_target)
       
        loss_critic = loss(x,y)
        loss_critic.backward()
        
        EMA(critic,critic_target,1)
        optimizer_critic.step()
        
        
        #actor loop
        optimizer_actor.zero_grad()
        
        actions = agent.compute_action(state_batch,deterministic=True)
        input_critic =  torch.cat((state_batch,actions),dim=1)
        critic_output = critic(input_critic)
        loss_actor  = -torch.mean(critic_output)
        loss_actor.backward()
        EMA(agent.model,target_agent.model,1)
        optimizer_actor.step()
        
        
        
        return (loss_critic.item() , loss_actor.item())

# %%
env = NormalizedEnv(gym.make('Pendulum-v1'))
#agent = RandomAgent(env)

# Set the environment to the initial state
state = env.reset()
average_total_reward = 0
# Run the simulation for 10 time steps
losses_critic = []
losses_actor = []
episodic_rewards = []
for e in tqdm(range(episodes)):
    state = env.reset()[0]
    total_reward = 0
    episodic_loss_critic = 0
    episodic_loss_actor = 0
    for t in range(200):
        # Render the environment
        env.render()
        previous_state = state
        
        # Take a random action
        state=torch.from_numpy(state).to(device)
        action = agent.compute_action(state,False).detach().cpu().numpy()
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        
        total_reward += reward
        next_action = -1
        action = torch.from_numpy(action)
        sample = (previous_state,action,reward,next_state,next_action)
        buffer.add(sample)
        
        
        batches_indexes=buffer.sample_batch(batch_size)
        if buffer.num_samples >128:
            step_loss_critic, step_loss_actor = train_one_batch_a2c(critic,critic_target,agent,target_agent,buffer,batches_indexes)
            episodic_loss_critic+=step_loss_critic
            episodic_loss_actor+=step_loss_actor
        
        
    losses_critic.append(episodic_loss_critic)
    losses_actor.append(episodic_loss_actor)
    episodic_rewards.append(total_reward)
    # Close the environment
    average_total_reward+=total_reward/num_episodes
env.close()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [22:27<00:00,  1.35s/it]

# %%
import matplotlib.pyplot as plt
x=list(range(len(losses_critic)))
y=losses_critic
plt.plot(x,y)
plt.savefig('figures/critic loss no ema.png')

# %%
import matplotlib.pyplot as plt
x=list(range(len(losses_critic)))
y=losses_actor
plt.plot(x,y)
plt.savefig('figures/actor loss no ema.png')

# %%
import matplotlib.pyplot as plt
x=list(range(len(losses_critic)))
y=episodic_rewards
plt.plot(x,y)
plt.savefig('figures/episodic reward no ema.png')

# %%
p

# %%
env = NormalizedEnv(gym.make('Pendulum-v1'))
#agent = RandomAgent(env)

# Set the environment to the initial state
state = env.reset()
average_total_reward = 0
# Run the simulation for 10 time steps

episodic_rewards = []
for e in tqdm(range(10)):
    state = env.reset()[0]
    total_reward = 0

    for t in range(200):
        # Render the environment
        env.render()
        previous_state = state
        
        # Take a random action
        state=torch.from_numpy(state).to(device)
        action = agent.compute_action(state,True).detach().cpu().numpy()
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        
        total_reward += reward
        next_action = -1
        action = torch.from_numpy(action)
       
    episodic_rewards.append(total_reward)
    # Close the environment
    average_total_reward+=total_reward/num_episodes
env.close()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 11.60it/s]

# %%
print('average episodic cumloss:',sum(episodic_rewards)/len(episodic_rewards))
# Out:
# average episodic cumloss: -204.76403516711073

# %%
polar_plot(-0.6,-0.6,critic,'A2C')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:19: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:23: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolormesh(th, r, z)

# %%
polar_plot(-0.0,0.6,critic,'A2C')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:19: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:23: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolormesh(th, r, z)

# %%
polar_plot(-0.0,0.0,critic,'A2C')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:19: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:23: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolormesh(th, r, z)

# %%
polar_plot(1.0,-0.6,critic,'A2C')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:19: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:23: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolormesh(th, r, z)

# %%
polar_plot(-4.0,0.8,critic,'A2C')
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:19: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\torge\AppData\Local\Temp\ipykernel_16716\565482560.py:23: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolormesh(th, r, z)

# %%
torch.save(critic.state_dict(), 'models/critic_no_ema.pth')
torch.save(actor.state_dict(), 'models/actor_no_ema.pth')

# %% [markdown]
# part 6

# %%
from tqdm import tqdm

buffer = Buffer(100000)


critic = Qnetwork().to(device)
critic_target = Qnetwork().to(device)
for param in critic_target.parameters():
        param.requires_grad = False
EMA(critic,critic_target,1)

sigma=0.3

actor = PolicyNetwork().to(device)
actor_target = PolicyNetwork().to(device)
for param in actor_target.parameters():
        param.requires_grad = False
EMA(actor,actor_target,1)
agent = DDPGAgent(actor,sigma,vanilla_noise=True)
target_agent = DDPGAgent(actor_target,sigma,True)
        

episodes=1000
batch_size=128
lr_critic=0.0001
lr_actor=0.0001
beta=0.005
gamma=0.99
loss=torch.nn.MSELoss()
optimizer_critic=torch.optim.Adam(critic.parameters(),lr_critic)
optimizer_actor=torch.optim.Adam(agent.model.parameters(),lr_actor)

#num_batches = buffer.capacity // batch_size
#permutation = torch.randperm(buffer.capacity)
#batches = torch.chunk(permutation[:num_batches * batch_size], num_batches)

# %%
def train_one_batch_a2c(critic,critic_target,agent,target_agent,buffer,indexes):
            
       
        
        action_batch = buffer.action_tape[indexes].to(device)
        state_batch = buffer.state_tape[indexes].to(device)
        next_state_batch = buffer.next_state_tape[indexes].to(device)
        reward_batch = buffer.reward_tape[indexes].to(device)
        
        
       
    
        #critic loop
        optimizer_critic.zero_grad()
        target_actions = target_agent.compute_action(next_state_batch,deterministic=True)
            
        input_model = torch.cat((state_batch,action_batch),dim=1)
        input_target = torch.cat((next_state_batch,target_actions),dim=1)
        
        x = critic(input_model)
        y = reward_batch + gamma*critic_target(input_target)
       
        loss_critic = loss(x,y)
        loss_critic.backward()
        
        optimizer_critic.step()
        EMA(critic,critic_target,beta)
        
        #actor loop
        optimizer_actor.zero_grad()
        
        actions = agent.compute_action(state_batch,deterministic=True)
        input_critic =  torch.cat((state_batch,actions),dim=1)
        critic_output = critic(input_critic)
        loss_actor  = -torch.mean(critic_output)
        loss_actor.backward()
        optimizer_actor.step()
        EMA(agent.model,target_agent.model,beta)
        
        
        return (loss_critic.item() , loss_actor.item())

# %% [markdown]
# ## Training for different values of \beta for EMA update

# %%
Betas= np.linspace(0.01,1,5)

# %%
Betas
# Out:
# array([0.01  , 0.2575, 0.505 , 0.7525, 1.    ])

# %%
States=[]
for betas in Betas:
    

    buffer = Buffer(100000)


    critic = Qnetwork().to(device)
    critic_target = Qnetwork().to(device)
    for param in critic_target.parameters():
            param.requires_grad = False
    EMA(critic,critic_target,1)

    sigma=0.3

    actor = PolicyNetwork().to(device)
    actor_target = PolicyNetwork().to(device)
    for param in actor_target.parameters():
            param.requires_grad = False
    EMA(actor,actor_target,1)
    agent = DDPGAgent(actor,sigma,vanilla_noise=True,theta=theta)
    target_agent = DDPGAgent(actor_target,sigma,True,theta)


    episodes=1000
    batch_size=128
    lr_critic=0.0001
    lr_actor=0.0001
    beta=betas
    gamma=0.99
    loss=torch.nn.MSELoss()
    optimizer_critic=torch.optim.Adam(critic.parameters(),lr_critic)
    optimizer_actor=torch.optim.Adam(agent.model.parameters(),lr_actor)
    
    
    print(agent.noise.theta)
    env = NormalizedEnv(gym.make('Pendulum-v1'))
    #agent = RandomAgent(env)

    # Set the environment to the initial state
    state = env.reset()
    average_total_reward = 0
    # Run the simulation for 10 time steps
    losses_critic = []
    losses_actor = []
    episodic_rewards = []
    for e in tqdm(range(episodes)):
        state = env.reset()[0]
        total_reward = 0
        episodic_loss_critic = 0
        episodic_loss_actor = 0
        for t in range(200):
            # Render the environment
            env.render()
            previous_state = state

            # Take a random action
            state=torch.from_numpy(state).to(device)
            action = agent.compute_action(state,False).detach().cpu().numpy()
            next_state, reward, terminated, truncated , info = env.step(action)
            state = next_state

            total_reward += reward
            next_action = -1
            action = torch.from_numpy(action)
            sample = (previous_state,action,reward,next_state,next_action)
            buffer.add(sample)


            batches_indexes=buffer.sample_batch(batch_size)
            if buffer.num_samples >128:
                step_loss_critic, step_loss_actor = train_one_batch_a2c(critic,critic_target,agent,target_agent,buffer,batches_indexes)
                episodic_loss_critic+=step_loss_critic
                episodic_loss_actor+=step_loss_actor


        losses_critic.append(episodic_loss_critic)
        losses_actor.append(episodic_loss_actor)
        episodic_rewards.append(total_reward)
        # Close the environment
        average_total_reward+=total_reward/num_episodes
        # Close the environment
        average_total_reward+=total_reward/num_episodes
    torch.save(critic.state_dict(), 'models/critic_OU'+str(theta)+'.pth')
    torch.save(actor.state_dict(),'models/actorc_OU'+str(theta)+'.pth')
    
    
    
    
    States.append((losses_critic,losses_actor,episodic_rewards))   
    
    fig1 = plt.figure()
    x=list(range(len(losses_critic)))
    y=losses_critic
    plt.plot(x,y)
    plt.savefig('figures/critic loss EMA'+str(beta)+'.png')
    plt.show()
    plt.close(fig1)
    
    fig1 = plt.figure()
    x=list(range(len(losses_critic)))
    y=losses_actor
    plt.plot(x,y)
    plt.savefig('figures/actor loss EMA'+str(beta)+'.png')
    plt.show()
    plt.close(fig1)
    
    fig1 = plt.figure()
    x=list(range(len(losses_critic)))
    y=episodic_rewards
    plt.plot(x,y)
    plt.savefig('figures/episodic_rewards EMA'+str(beta)+'.png')
    plt.show()
    plt.close(fig1)
    
    
    
    env.close()

# %% [markdown]
# ## Training for different values of \theta for OU noise

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17512\2273761208.py in <module>
# ----> 1 plt.figure()
#
# TypeError: 'Figure' object is not callable

# %%
thetas= np.linspace(0,1,5)

# %% [markdown]
# Theta = 1 is just the usual normal noise so we decided to add the value of 0.15 which we tried before and gave us a good model that managed to get the pendulum stuck in upward by appliying the correct torqe

# %%
thetas=[0.15]

# %%
States=[]
for theta in thetas:
    

    buffer = Buffer(100000)


    critic = Qnetwork().to(device)
    critic_target = Qnetwork().to(device)
    for param in critic_target.parameters():
            param.requires_grad = False
    EMA(critic,critic_target,1)

    sigma=0.3

    actor = PolicyNetwork().to(device)
    actor_target = PolicyNetwork().to(device)
    for param in actor_target.parameters():
            param.requires_grad = False
    EMA(actor,actor_target,1)
    agent = DDPGAgent(actor,sigma,vanilla_noise=False,theta=theta)
    target_agent = DDPGAgent(actor_target,sigma,False,theta)


    episodes=1
    batch_size=128
    lr_critic=0.0001
    lr_actor=0.0001
    beta=0.01
    gamma=0.99
    loss=torch.nn.MSELoss()
    optimizer_critic=torch.optim.Adam(critic.parameters(),lr_critic)
    optimizer_actor=torch.optim.Adam(agent.model.parameters(),lr_actor)
    
    
    print(agent.noise.theta)
    env = NormalizedEnv(gym.make('Pendulum-v1'))
    #agent = RandomAgent(env)

    # Set the environment to the initial state
    state = env.reset()
    average_total_reward = 0
    # Run the simulation for 10 time steps
    losses_critic = []
    losses_actor = []
    episodic_rewards = []
    for e in tqdm(range(episodes)):
        state = env.reset()[0]
        total_reward = 0
        episodic_loss_critic = 0
        episodic_loss_actor = 0
        for t in range(200):
            # Render the environment
            env.render()
            previous_state = state

            # Take a random action
            state=torch.from_numpy(state).to(device)
            action = agent.compute_action(state,False).detach().cpu().numpy()
            next_state, reward, terminated, truncated , info = env.step(action)
            state = next_state

            total_reward += reward
            next_action = -1
            action = torch.from_numpy(action)
            sample = (previous_state,action,reward,next_state,next_action)
            buffer.add(sample)


            batches_indexes=buffer.sample_batch(batch_size)
            if buffer.num_samples >128:
                step_loss_critic, step_loss_actor = train_one_batch_a2c(critic,critic_target,agent,target_agent,buffer,batches_indexes)
                episodic_loss_critic+=step_loss_critic
                episodic_loss_actor+=step_loss_actor


        losses_critic.append(episodic_loss_critic)
        losses_actor.append(episodic_loss_actor)
        episodic_rewards.append(total_reward)
        # Close the environment
        average_total_reward+=total_reward/num_episodes
        # Close the environment
        average_total_reward+=total_reward/num_episodes
    torch.save(critic.state_dict(), 'models/critic_OU'+str(theta)+'.pth')
    torch.save(actor.state_dict(),'models/actorc_OU'+str(theta)+'.pth')
    
    
    
    
    States.append((losses_critic,losses_actor,episodic_rewards))   
    
    fig1 = plt.figure()
    x=list(range(len(losses_critic)))
    y=losses_critic
    plt.plot(x,y)
    plt.savefig('figures/critic loss OU'+str(theta)+'.png')
    plt.show()
    plt.close(fig1)
    
    fig1 = plt.figure()
    x=list(range(len(losses_critic)))
    y=losses_actor
    plt.plot(x,y)
    plt.savefig('figures/actor loss OU'+str(theta)+'.png')
    plt.show()
    plt.close(fig1)
    
    fig1 = plt.figure()
    x=list(range(len(losses_critic)))
    y=episodic_rewards
    plt.plot(x,y)
    plt.savefig('figures/episodic_rewards OU'+str(theta)+'.png')
    plt.show()
    plt.close(fig1)
    
    
    
    env.close()
# Out:
# 0.0
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.64it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17512\248204289.py in <module>
#      90     States.append((losses_critic,losses_actor,episodic_rewards))
#      91
# ---> 92     fig1 = plt.figure()
#      93     x=list(range(len(losses_critic)))
#      94     y=losses_critic
#
# TypeError: 'Figure' object is not callable

# %% [markdown]
# ## Running the Test loops for the models obtained by changing the Beta and Theta

# %% [markdown]
# ### betas

# %%
Betas= np.linspace(0.01,1,5)

# %%
paths=[]
for beta in Betas:
    path='./models/actorc_ema'+str(beta)+'.pth'
    paths.append(path)

# %%
paths
# Out:
# ['./models/actorc_ema0.01.pth',
#  './models/actorc_ema0.2575.pth',
#  './models/actorc_ema0.505.pth',
#  './models/actorc_ema0.7525.pth',
#  './models/actorc_ema1.0.pth']

# %%
rewards=[]
for path in paths:
    actor = PolicyNetwork().to(device)
    actor.load_state_dict(torch.load(path))
    agent = DDPGAgent(actor,0.3,vanilla_noise=False)

    # Create the Pendulum environment

    env = NormalizedEnv(gym.make('Pendulum-v1'))
    #agent = RandomAgent(env)
    frames = []
    # Set the environment to the initial state
    state = env.reset()
    average_total_reward = 0
    # Run the simulation for 10 time steps
    for e in tqdm(range(1000)):
        state = env.reset()[0]
        total_reward = 0
        for t in range(200):
            # Render the environment
            env.render()
            frames.append(env.render())
            # Take a random action
            state=torch.from_numpy(state).to(device)
            action = agent.compute_action(state,True).detach().cpu().numpy()
            #print(action)
            next_state, reward, terminated, truncated , info = env.step(action)
            state = next_state
            total_reward += reward
        # Close the environment
        average_total_reward+=total_reward/1000
    rewards.append(average_total_reward)
        
    env.close()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:00<00:00,  8.30it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:18<00:00, 12.70it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:19<00:00, 12.61it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:19<00:00, 12.62it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:19<00:00, 12.55it/s]

# %%
rewards
# Out:
# [-146.95908373889878,
#  -154.18324096372567,
#  -151.38487204334132,
#  -160.075418916063,
#  -148.75640640805022]

# %%
plt.plot(Betas,rewards)
plt.xlabel('Beta')
plt.ylabel('average episodic reward')
plt.savefig('figures/test_reward_vs_beta.png')

# %% [markdown]
# ## Thetas

# %%
Thetas=[0.0,0.15,0.25,0.5,0.75]

# %%
paths=[]
for theta in Thetas:
    path='./models/actorc_OU'+str(theta)+'.pth'
    paths.append(path)

# %%
paths
# Out:
# ['./models/actorc_OU0.0.pth',
#  './models/actorc_OU0.15.pth',
#  './models/actorc_OU0.25.pth',
#  './models/actorc_OU0.5.pth',
#  './models/actorc_OU0.75.pth']

# %%
num_episodes
# Out:
# 1000

# %%
rewards=[]
for path in paths:
    actor = PolicyNetwork().to(device)
    actor.load_state_dict(torch.load(path))
    agent = DDPGAgent(actor,0.3,vanilla_noise=False)

    # Create the Pendulum environment

    env = NormalizedEnv(gym.make('Pendulum-v1'))
    #agent = RandomAgent(env)
    frames = []
    # Set the environment to the initial state
    state = env.reset()
    average_total_reward = 0
    # Run the simulation for 10 time steps
    for e in tqdm(range(1000)):
        state = env.reset()[0]
        total_reward = 0
        for t in range(200):
            # Render the environment
            env.render()
            frames.append(env.render())
            # Take a random action
            state=torch.from_numpy(state).to(device)
            action = agent.compute_action(state,True).detach().cpu().numpy()
            #print(action)
            next_state, reward, terminated, truncated , info = env.step(action)
            state = next_state
            total_reward += reward
        # Close the environment
        average_total_reward+=total_reward/1000
    rewards.append(average_total_reward)
        
    env.close()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:17<00:00, 12.89it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:17<00:00, 12.90it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:17<00:00, 12.84it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:18<00:00, 12.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:17<00:00, 12.87it/s]

# %%
rewards

# %%
plt.plot(Thetas,rewards)
plt.xlabel('Theta')
plt.ylabel('average episodic reward')
plt.savefig('figures/test_reward_vs_Theta.png')

# %% [markdown]
# ## POLAR PLOTS

# %%
place_holder = Qnetwork().to(device)

# %%
before_train = Qnetwork().to(device)
after_train = Qnetwork().to(device)
after_train.load_state_dict(torch.load('./models/critic_no_actor.pth'))
a2c = Qnetwork().to(device)
a2c.load_state_dict(torch.load('./models/critic_ema1.0.pth'))
# Out:
# <All keys matched successfully>

# %%
speed = 4.0
action = 0.6
polar_plot(speed,action,before_train,'before_train')
polar_plot(speed,action,after_train,'after_train')
polar_plot(speed,action,a2c,'a2c')

# %% [markdown]
# ## To get the cool Gif

# %%
    actor = PolicyNetwork().to(device)
    actor.load_state_dict(torch.load('./models/actorc_ema1.0.pth'))
    agent = DDPGAgent(actor,0.3,vanilla_noise=False)

# %%
    # Create the Pendulum environment

    env = NormalizedEnv(gym.make('Pendulum-v1',render_mode="rgb_array"))
    #agent = RandomAgent(env)
    frames = []
    # Set the environment to the initial state
    state = env.reset()
    average_total_reward = 0
    # Run the simulation for 10 time steps
    for e in range(1):
        state = env.reset()[0]
        total_reward = 0
        for t in range(2000):
            # Render the environment
            env.render()
            frames.append(env.render())
            # Take a random action
            state=torch.from_numpy(state).to(device)
            action = agent.compute_action(state,True).detach().cpu().numpy()
            #print(action)
            next_state, reward, terminated, truncated , info = env.step(action)
            state = next_state
            total_reward += reward
        # Close the environment
        average_total_reward+=total_reward/num_episodes
        
    env.close()

# %%
from matplotlib import animation
import matplotlib.pyplot as plt
import gym 

"""
Ensure you have imagemagick installed with 
sudo apt-get install imagemagick
Open file in CLI with:
xgd-open <filelname>
"""
def save_frames_as_gif(frames, path='./', filename='best_model.gif'):

    #Mess with this to change frame size
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi=72)

    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
    anim.save(path + filename, writer='Pillow', fps=60)


save_frames_as_gif(frames)
# Out:
# MovieWriter Pillow unavailable; using Pillow instead.

# %%
# Create the Pendulum environment
env = NormalizedEnv(gym.make('Pendulum-v1',render_mode="human"))
#agent = RandomAgent(env)

# Set the environment to the initial state
state = env.reset()
average_total_reward = 0
# Run the simulation for 10 time steps
for e in range(10):
    state = env.reset()[0]
    total_reward = 0
    for t in range(200):
        # Render the environment
        env.render()

        # Take a random action
        state=torch.from_numpy(state).to(device)
        action = agent.compute_action(state,True).detach().cpu().numpy()
        print(action)
        next_state, reward, terminated, truncated , info = env.step(action)
        state = next_state
        total_reward += reward
    # Close the environment
    average_total_reward+=total_reward/num_episodes
env.close()
# Out:
# [0.05352396]
# [-0.32986644]
# [0.74579763]
# [0.8625349]
# [0.9050469]
# [0.8960515]
# [0.875044]
# [0.6234367]
# [0.06471458]
# [-0.38453078]
# [-0.581989]
# [-0.7889633]
# [-0.8789312]
# [-0.41084492]
# [0.07781205]
# [0.40176332]
# [-0.26264873]
# [0.45491323]
# [-0.37171715]
# [-0.30826682]
# [-0.29647684]
# [-0.7023717]
# [-0.7319603]
# [-0.10950054]
# [0.0285044]
# [-0.11683425]
# [-0.56991196]
# [-0.52259094]
# [-0.53370297]
# [-0.46730196]
# [-0.37221575]
# [-0.29608795]
# [-0.22662725]
# [-0.25417253]
# [-0.16578689]
# [-0.08918192]
# [0.2615352]
# [0.38194737]
# [0.4679899]
# [0.5554898]
# [0.59475464]
# [0.61084807]
# [0.61304206]
# [0.60643387]
# [0.59430975]
# [0.5790722]
# [0.5625831]
# [0.54626673]
# [0.53113633]
# [0.51781774]
# [0.5066038]
# [0.49751815]
# [0.49041775]
# [0.4850525]
# [0.4811325]
# [0.4783755]
# [0.47651476]
# [0.4753286]
# [0.47463217]
# [0.4742769]
# [0.4741529]
# [0.47417322]
# [0.4742817]
# [0.47443414]
# [0.47460094]
# [0.4747677]
# [0.4749197]
# [0.47505486]
# [0.47516784]
# [0.4752627]
# [0.47533837]
# [0.4753985]
# [0.475443]
# [0.47547677]
# [0.4755024]
# [0.4755194]
# [0.47552973]
# [0.47553894]
# [0.47554392]
# [0.47554502]
# [0.47554633]
# [0.47554687]
# [0.47554615]
# [0.47554615]
# [0.47554448]
# [0.4755443]
# [0.4755432]
# [0.47554207]
# [0.47554153]
# [0.47554117]
# [0.47554043]
# [0.47554097]
# [0.47553968]
# [0.47553986]
# [0.47553912]
# [0.47553933]
# [0.47553876]
# [0.47553912]
# [0.47553894]
# [0.4755384]
# [0.47554117]
# [0.47553968]
# [0.47553968]
# [0.47553876]
# [0.47553912]
# [0.47553894]
# [0.47553858]
# [0.47554004]
# [0.47553858]
# [0.47554025]
# [0.47554025]
# [0.47553986]
# [0.4755395]
# [0.47553968]
# [0.47553858]
# [0.47553894]
# [0.47553894]
# [0.47554004]
# [0.47553876]
# [0.47554004]
# [0.47553876]
# [0.47554025]
# [0.47553986]
# [0.4755395]
# [0.4755395]
# [0.47553876]
# [0.47553912]
# [0.47553858]
# [0.47554004]
# [0.47553876]
# [0.47554025]
# [0.47554025]
# [0.47553968]
# [0.47553876]
# [0.47553912]
# [0.47553894]
# [0.4755384]
# [0.4755406]
# [0.47554025]
# [0.47553968]
# [0.47553876]
# [0.47553912]
# [0.47553894]
# [0.47553858]
# [0.47554025]
# [0.47553933]
# [0.4755406]
# [0.47553968]
# [0.47553876]
# [0.47553912]
# [0.47
# [0.47847956]
# [0.47661978]
# [0.4754277]
# [0.47471952]
# [0.47435117]
# [0.4742126]
# [0.47422385]
# [0.4743205]
# [0.47446296]
# [0.47462404]
# [0.47478306]
# [0.474933]
# [0.4750628]
# [0.47517392]
# [0.47526565]
# [0.47534004]
# [0.47539797]
# [0.475443]
# [0.47547713]
# [0.47550204]
# [0.4755183]
# [0.47552952]
# [0.4755384]
# [0.47554263]
# [0.47554466]
# [0.47554633]
# [0.47554687]
# [0.47554576]
# [0.47554576]
# [0.47554523]
# [0.4755432]
# [0.47554412]
# [0.47554135]
# [0.47554025]
# [0.4755408]
# [0.47553968]
# [0.4755408]
# [0.47554004]
# [0.47554025]
# [0.47553876]
# [0.47553876]
# [0.47553894]
# [0.47553933]
# [0.4755406]
# [0.47553894]
# [0.47553912]
# [0.47553894]
# [0.4755406]
# [0.47553894]
# [0.47553912]
# [0.47553894]
# [0.47553858]
# [0.47554025]
# [0.47553858]
# [0.47554025]
# [0.47554043]
# [0.47553933]
# [0.47554025]
# [0.47553933]
# [0.47553858]
# [0.47553894]
# [0.4755382]
# [0.47554117]
# [0.47553968]
# [0.4755395]
# [0.47553894]
# [0.47553894]
# [0.47553876]
# [0.4755406]
# [0.47553858]
# [0.4755384]
# [0.47554117]
# [0.47553968]
# [0.4755395]
# [0.47553876]
# [0.47553912]
# [0.47553858]
# [0.47554004]
# [0.47553912]
# [0.47554025]
# [0.47553986]
# [0.4755395]
# [0.47553894]
# [0.47553894]
# [0.47553894]
# [0.47554004]
# [0.47553876]
# [0.47554004]
# [0.47553876]
# [0.47554025]
# [0.47553986]
# [0.47553912]
# [0.4755395]
# [0.4755395]
# [0.4755395]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11996\1832723992.py in <module>
#      12     for t in range(200):
#      13         # Render the environment
# ---> 14         env.render()
#      15
#      16         # Take a random action
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, *args, **kwargs)
#     327     ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328         """Renders the environment."""
# --> 329         return self.env.render(*args, **kwargs)
#     330
#     331     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, *args, **kwargs)
#     327     ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328         """Renders the environment."""
# --> 329         return self.env.render(*args, **kwargs)
#     330
#     331     def close(self):
#
# ~\anaconda3\lib\site-packages\gym\wrappers\order_enforcing.py in render(self, *args, **kwargs)
#      49                 "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50             )
# ---> 51         return self.env.render(*args, **kwargs)
#      52
#      53     @property
#
# ~\anaconda3\lib\site-packages\gym\wrappers\env_checker.py in render(self, *args, **kwargs)
#      53             return env_render_passive_checker(self.env, *args, **kwargs)
#      54         else:
# ---> 55             return self.env.render(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\gym\envs\classic_control\pendulum.py in render(self)
#     251         if self.render_mode == "human":
#     252             pygame.event.pump()
# --> 253             self.clock.tick(self.metadata["render_fps"])
#     254             pygame.display.flip()
#     255
#
# KeyboardInterrupt:

# %%
polar_plot(-5.0,1.0,critic)
# Out:
# C:\Users\torge\AppData\Local\Temp\ipykernel_18840\1247305180.py:19: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# C:\Users\torge\AppData\Local\Temp\ipykernel_18840\1247305180.py:23: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolormesh(th, r, z)
